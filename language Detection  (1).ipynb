# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import library

# %%
import numpy as np
import pandas as pd

# %%
# !ls "/content/drive/MyDrive/"
# Out:
#  Adjectives_into_nouns.pdf
# 'Admission_Declaration_form (1).pdf'
#  Admission_Declaration_form.pdf
# 'Audio from 100rabh🤙🏻'
#  bank.pdf
#  CNN_ShoeClassification.ipynb
# 'CNN test'
# 'CNN train'
# 'Colab Notebooks'
# 'Cp1_Saurabh_pandey (1).pdf'
# 'Cp1 saurabh_pandey(@).pdf'
#  Cp1_Saurabh_pandey.pdf
#  Cp_netflix.pdf
# 'Differentiate between TCP and UDP.gsheet'
# 'DL + AI Exam Paper (1)'
# 'Getting started.pdf'
#  IMG-20200810-WA0033.pdf
#  language.csv
# 'language Detection .ipynb'
#  Language_Detection_Proposal.pdf
#  mu1.pdf
# 'mu 2.pdf'
# 'my resume (1).pdf'
# 'my resume.pdf'
# 'rachita doc.docx'
#  reportsXXXXXXXXXX9151_20210528173930811441.pdf
#  rnn
# 'RNN DL exam (1).ipynb'
#  rnn_test
# 'Saurabh_Pandey_Resume_ (1).pdf'
# 'Saurabh_Pandey_Resume_ (2).pdf'
# 'Saurabh_Pandey_Resume_ (3).pdf'
# 'Saurabh_Pandey_Resume_ (4).pdf'
# 'Saurabh_Pandey_Resume_ (5).pdf'
#  Saurabh_Pandey_Resume.pdf
#  Saurabh_Pandey_Resume_.pdf
#  Screenshot_20200729-124703.pdf
# ...

# %%
data = pd.read_csv('/content/drive/MyDrive/language.csv')
data.head()
# Out:
#                                                 Text  language
# 0  klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1  sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2  ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3  விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4  de spons behoort tot het geslacht haliclona en...     Dutch

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
#data cleaning

# %%
data.isnull()
# Out:
#         Text  language
# 0      False     False
# 1      False     False
# 2      False     False
# 3      False     False
# 4      False     False
# ...      ...       ...
# 21995  False     False
# 21996  False     False
# 21997  False     False
# 21998  False     False
# 21999  False     False
#
# [22000 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# Text        0
# language    0
# dtype: int64

# %%
data['language'].value_counts()
# Out:
# language
# Estonian      1000
# Swedish       1000
# Thai          1000
# Tamil         1000
# Dutch         1000
# Japanese      1000
# Turkish       1000
# Latin         1000
# Urdu          1000
# Indonesian    1000
# Portugese     1000
# French        1000
# Chinese       1000
# Korean        1000
# Hindi         1000
# Spanish       1000
# Pushto        1000
# Persian       1000
# Romanian      1000
# Russian       1000
# English       1000
# Arabic        1000
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
lang_counts = data['language'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(lang_counts.index, lang_counts.values,color='green')
plt.title('Language Distribution')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data.dtypes
# Out:
# Text        object
# language    object
# dtype: object

# %%
x = np.array(data['Text'])
y = np.array(data['language'])

# %%
x
# Out:
# array(['klement gottwaldi surnukeha palsameeriti ning paigutati mausoleumi surnukeha oli aga liiga hilja ja oskamatult palsameeritud ning hakkas ilmutama lagunemise tundemärke  aastal viidi ta surnukeha mausoleumist ära ja kremeeriti zlíni linn kandis aastatel – nime gottwaldov ukrainas harkivi oblastis kandis zmiivi linn aastatel – nime gotvald',
#        'sebes joseph pereira thomas  på eng the jesuits and the sino-russian treaty of nerchinsk  the diary of thomas pereira bibliotheca instituti historici s i --   rome libris ',
#        'ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เริ่มตั้งแต่ถนนสนามไชยถึงแม่น้ำเจ้าพระยาที่ถนนตก กรุงเทพมหานคร เป็นถนนรุ่นแรกที่ใช้เทคนิคการสร้างแบบตะวันตก ปัจจุบันผ่านพื้นที่เขตพระนคร เขตป้อมปราบศัตรูพ่าย เขตสัมพันธวงศ์ เขตบางรัก เขตสาทร และเขตบางคอแหลม',
#        ...,
# ...

# %%
print(y)
# Out:
# ['Estonian' 'Swedish' 'Thai' ... 'Spanish' 'Chinese' 'Romanian']

# %%
#converting data from text to numerical
cv = CountVectorizer()
X = cv.fit_transform(x)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
print(y)
# Out:
# [ 4 17 19 ... 16  1 14]

# %%
#train test
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.33, random_state= 42)

# %%
X_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 613529 stored elements and shape (14740, 277720)>

# %%
print(X_train) #data has been converted to numeber
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 613529 stored elements and shape (14740, 277720)>
#   Coords	Values
#   (0, 197295)	2
#   (0, 197708)	1
#   (0, 197801)	1
#   (0, 198388)	1
#   (0, 197467)	1
#   (0, 197865)	2
#   (0, 197604)	1
#   (0, 198428)	1
#   (0, 198501)	1
#   (0, 198556)	1
#   (0, 197332)	1
#   (0, 197485)	2
#   (0, 198123)	1
#   (0, 197892)	1
#   (0, 197990)	1
#   (0, 198053)	1
#   (0, 198417)	1
#   (0, 197623)	1
#   (1, 197641)	2
#   (1, 197314)	1
#   (1, 197931)	1
#   (1, 197804)	3
#   (1, 198397)	1
#   (1, 197149)	1
#   (1, 197781)	1
#   :	:
#   (14738, 188817)	1
#   (14738, 192004)	1
#   (14738, 157171)	1
#   (14738, 190346)	1
#   (14738, 190725)	1
#   (14738, 189685)	1
#   (14738, 159269)	2
#   (14738, 145431)	1
#   (14738, 173292)	1
#   (14738, 176062)	1
#   (14738, 159959)	1
#   (14738, 190198)	1
#   (14738, 167124)	1
#   (14738, 168158)	1
#   (14738, 180260)	2
#   (14738, 153262)	1
#   (14738, 162150)	1
#   (14738, 153355)	1
# ...

# %%
#model building

model = MultinomialNB()

# %%
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
#model accuracy
model.score(X_test,y_test)
# Out:
# 0.953168044077135

# %%
from sklearn.metrics import classification_report

y_pred_nb = model.predict(X_test)

print("Naive Bayes Classification Report:\n")
print(classification_report(y_test, y_pred_nb))
# Out:
# Naive Bayes Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       341
#            1       0.93      0.50      0.65       317
#            2       0.99      0.99      0.99       346
#            3       0.70      1.00      0.82       333
#            4       0.99      0.96      0.97       338
#            5       0.95      0.99      0.97       324
#            6       1.00      0.98      0.99       341
#            7       0.99      0.97      0.98       318
#            8       0.69      0.87      0.77       328
#            9       1.00      0.98      0.99       325
#           10       0.99      0.91      0.95       346
#           11       1.00      1.00      1.00       323
#           12       1.00      0.96      0.98       318
#           13       1.00      0.97      0.98       328
#           14       0.99      0.98      0.99       324
#           15       0.99      0.99      0.99       332
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB

#defining the param grid
param_grid = {'alpha': [0.01, 0.1, 0.5, 1.0, 2.0]}

#passing variable to the model
nb = MultinomialNB()

#GRID search
grid_search= GridSearchCV(nb, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

#checking the best param and score
print("Best Alpha:",grid_search.best_params_)
print("Best CV Accuracy:", grid_search.best_score_)

#predicting the best model
best_nb = grid_search.best_estimator_
y_pred_best = best_nb.predict(X_test)

#model evalution
from sklearn.metrics import classification_report
print("\nTuned Naive Bayes Classification Report:")
print(classification_report(y_test, y_pred_best))
# Out:
# Best Alpha: {'alpha': 0.1}
# Best CV Accuracy: 0.9582089552238806
#
# Tuned Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       341
#            1       0.94      0.51      0.67       317
#            2       0.99      0.99      0.99       346
#            3       0.74      1.00      0.85       333
#            4       0.99      0.96      0.98       338
#            5       0.96      0.99      0.98       324
#            6       0.99      0.98      0.99       341
#            7       0.99      0.97      0.98       318
#            8       0.67      0.92      0.77       328
#            9       1.00      0.98      0.99       325
#           10       0.99      0.92      0.95       346
#           11       1.00      1.00      1.00       323
#           12       1.00      0.97      0.98       318
#           13       1.00      0.96      0.98       328
# ...

# %%
user_input = input("Enter a text: ")
vec_input = cv.transform([user_input]).toarray()
encoded_pred = model.predict(vec_input)
predicted_language = label_encoder.inverse_transform([encoded_pred[0]])
print('predicted_language',str(predicted_language[0]))
# Out:
# Enter a text: ik ben
# predicted_language Portugese

# %%
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

lr_accuracy= lr_model.score(X_test, y_test)
print("Logistic Regression Model Accuracy:", lr_accuracy)
# Out:
# Logistic Regression Model Accuracy: 0.9431129476584023

# %%
#more clear and better understanding in classification report than heatmap
y_pred_lr = lr_model.predict(X_test)
print("Logistic Regression Classification Report:\n")
print(classification_report(y_test, y_pred_lr))
# Out:
# Logistic Regression Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       341
#            1       0.75      0.50      0.60       317
#            2       1.00      0.98      0.99       346
#            3       0.90      0.97      0.93       333
#            4       0.97      0.94      0.96       338
#            5       0.98      0.98      0.98       324
#            6       1.00      0.97      0.99       341
#            7       1.00      0.97      0.99       318
#            8       0.52      0.92      0.67       328
#            9       1.00      0.91      0.95       325
#           10       0.94      0.91      0.92       346
#           11       1.00      0.98      0.99       323
#           12       0.98      0.98      0.98       318
#           13       1.00      0.95      0.98       328
#           14       1.00      0.97      0.98       324
# ...

# %%
# !ls *.pkl
# Out:
# ls: cannot access '*.pkl': No such file or directory

# %%
#  Logistic Regression confusion matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)
plt.figure(figsize=(12, 8))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Greens')
plt.title("Confusion Matrix - Logistic Regression"
plt.show()

# %%
#Deep Learning LSTM model

# %%
data = pd.read_csv('/content/drive/MyDrive/language.csv')

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenizer setup
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(data['Text'])

# Convert to sequences
sequences = tokenizer.texts_to_sequences(data['Text'])

# Padding
max_len = 100
padded = pad_sequences(sequences, maxlen=max_len, padding='post')

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(data['language'])

# %%
# checking label assign to the languages
for i, class_name in enumerate(label_encoder.classes_):
    print(f"{i}: {class_name}")
# Out:
# 0: Arabic
# 1: Chinese
# 2: Dutch
# 3: English
# 4: Estonian
# 5: French
# 6: Hindi
# 7: Indonesian
# 8: Japanese
# 9: Korean
# 10: Latin
# 11: Persian
# 12: Portugese
# 13: Pushto
# 14: Romanian
# 15: Russian
# 16: Spanish
# 17: Swedish
# 18: Tamil
# 19: Thai
# 20: Turkish
# 21: Urdu

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(padded, labels, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=64, input_length=max_len))
model.add(LSTM(64))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test))
# Out:
# Epoch 1/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.0796 - loss: 2.9933 - val_accuracy: 0.1000 - val_loss: 2.7770
# Epoch 2/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.1348 - loss: 2.6637 - val_accuracy: 0.3700 - val_loss: 1.7512
# Epoch 3/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.4182 - loss: 1.6759 - val_accuracy: 0.5852 - val_loss: 1.1413
# Epoch 4/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 33s 61ms/step - accuracy: 0.6675 - loss: 0.9179 - val_accuracy: 0.8084 - val_loss: 0.5416
# Epoch 5/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 39s 56ms/step - accuracy: 0.8154 - loss: 0.5499 - val_accuracy: 0.8611 - val_loss: 0.3955
# Epoch 6/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 41s 57ms/step - accuracy: 0.8580 - loss: 0.4027 - val_accuracy: 0.8698 - val_loss: 0.3806
# Epoch 7/15
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.8996 - loss: 0.2949 - val_accuracy: 0.8705 - val_loss: 0.3428
# Epoch 8/15
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("LSTM Model Accuracy:", accuracy)
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9120 - loss: 0.2392
# LSTM Model Accuracy: 0.9136363863945007

# %%
import pickle

# Save the trained Naive Bayes model
with open("nb_model.pkl", "wb") as f:
    pickle.dump(model, f)

# Save the CountVectorizer
with open("vectorizer.pkl", "wb") as f:
    pickle.dump(cv, f)

# Save the LabelEncoder
with open("label_encoder.pkl", "wb") as f:
    pickle.dump(label_encoder, f)

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 106.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import pickle
import numpy as np

# Load all pickle files
with open("nb_model.pkl", "rb") as f:
    model = pickle.load(f)

with open("vectorizer.pkl", "rb") as f:
    cv = pickle.load(f)

with open("label_encoder.pkl", "rb") as f:
    label_encoder = pickle.load(f)

# Define prediction function
def predict_language(text):
    try:
        vec = cv.transform([text]).toarray()
        pred = model.predict(vec)
        language = label_encoder.inverse_transform(pred)
        return language[0]
    except Exception as e:
        return f"❌ Error: {e}"

# Gradio interface
iface = gr.Interface(
    fn=predict_language,
    inputs=gr.Textbox(lines=2, placeholder="Enter a sentence..."),
    outputs="text",
    title="🌐 Language Detection with Naive Bayes",
    description="Enter a sentence and this model will detect the language using Naive Bayes algorithm."
)

# Launch the app
iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5be0e8a939b40872da.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5be0e8a939b40872da.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
